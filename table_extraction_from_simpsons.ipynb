# %%
import pandas as pd

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

html_string = StringIO(response.text)
simpsons = pd.read_html(html_string)

# %%
len(simpsons)
# Out:
# 24

# %%
simpsons[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
#                            Directed by  \
# 0                      David Silverman
# 1                      David Silverman
# 2                           Wes Archer
# 3       Gregg Vanzo & Kent Butterworth
# 4                      David Silverman
# 5                           Wes Archer
# 6                           Wes Archer
# 7                           Rich Moore
# 8                      David Silverman
# 9                           Rich Moore
# 10            Wes Archer & Milton Gray
# 11                           Brad Bird
# 12  David Silverman & Kent Butterworth
#
#                                            Written by  Original release date  \
# 0                                           Mimi Pond  December 17, 1989[53]
# 1                                           Jon Vitti   January 14, 1990[55]
# 2                      Jay Kogen & Wallace Wolodarsky   January 21, 1990[56]
# 3                                Al Jean & Mike Reiss   January 28, 1990[58]
# 4                                   John Swartzwelder   February 4, 1990[60]
# 5                                Al Jean & Mike Reiss  February 11, 1990[62]
# 6                                   John Swartzwelder  February 18, 1990[64]
# 7      Al Jean, Mike Reiss, Sam Simon & Matt Groening  February 25, 1990[66]
# 8                                   John Swartzwelder     March 18, 1990[68]
# 9                                           Jon Vitti     March 25, 1990[70]
# 10  George Meyer, Sam Simon, John Swartzwelder & J...     April 15, 1990[72]
# 11                     Jay Kogen & Wallace Wolodarsky     April 29, 1990[74]
# 12                          Matt Groening & Sam Simon       May 13, 1990[76]
#
#    Prod. code U.S. viewers (millions)
# 0        7G08                26.7[54]
# 1        7G02                24.5[54]
# 2        7G03                27.5[57]
# 3        7G04                20.2[59]
# 4        7G05                27.1[61]
# 5        7G06                27.4[63]
# 6        7G09                27.6[65]
# 7        7G07                28.0[67]
# 8        7G11                33.5[69]
# 9        7G10                30.3[71]
# 10       7G13                31.2[73]
# 11       7G12                30.4[75]
# 12       7G01                27.1[77]

# %%
url = "https://www.bls.gov/data/"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36"
}

# %%
response = requests.get(url, headers=headers)

html_string = StringIO(response.text)
simpsons = pd.read_html(html_string)

# %%
len(simpsons)
# Out:
# 16

# %%
simpsons[1]
# Out:
#                                         Database Name  Special Notice  \
# 0                                             Monthly         Monthly
# 1   Employment, Hours, and Earnings - National  (C...             NaN
# 2   Employment, Hours, and Earnings - State and Me...             NaN
# 3   Labor Force Statistics  (Current Population Su...             NaN
# 4      Job Openings and Labor Turnover Survey (JOLTS)             NaN
# 5                                           Quarterly       Quarterly
# 6   State and County Employment and Wages  (Quarte...             NaN
# 7                  Business Employment Dynamics (BDM)             NaN
# 8                                      Annual & Other  Annual & Other
# 9   Occupational Employment and Wage Statistics (O...             NaN
# 10  Occupational Employment and Wage Statistics (O...             NaN
# 11                    American Time Use Survey (ATUS)             NaN
# 12  Union Affiliation Data  (Current Population Su...             NaN
# 13  Marital and family labor force statistics  (Cu...             NaN
# 14                             Employment Projections             NaN
# 15  National Longitudinal Surveys (NLS) (National ...             NaN
#
#         Top  Picks    Data  Finder     One  Screen  Multi-  Screen  \
# 0          Monthly         Monthly         Monthly         Monthly
# 1              NaN             NaN             NaN             NaN
# 2              NaN             NaN             NaN             NaN
# 3              NaN             NaN             NaN             NaN
# 4              NaN             NaN             NaN             NaN
# 5        Quarterly       Quarterly       Quarterly       Quarterly
# 6              NaN             NaN             NaN             NaN
# 7              NaN             NaN             NaN             NaN
# 8   Annual & Other  Annual & Other  Annual & Other  Annual & Other
# 9              NaN             NaN             NaN             NaN
# 10             NaN             NaN             NaN             NaN
# 11             NaN             NaN             NaN             NaN
# 12             NaN             NaN             NaN             NaN
# 13             NaN             NaN             NaN             NaN
# 14             NaN             NaN             NaN             NaN
# 15             NaN             NaN             NaN             NaN
#
#             Tables      Text Files
# 0          Monthly         Monthly
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5        Quarterly       Quarterly
# 6              NaN             NaN
# 7              NaN             NaN
# 8   Annual & Other  Annual & Other
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
