# %%
import csv

# %%
example_file = open('example3.csv')

# %%
example_reader = csv.reader(example_file)

# %%
example_data = list(example_reader)

# %%
example_data
# Out:
# [['4/5/2035 13:34', 'Apples', '73'],
#  ['4/5/2035 3:41', 'Cherries', '85'],
#  ['4/6/2035 12:46', 'Pears', '14'],
#  ['4/8/2035 8:59', 'Oranges', '52'],
#  ['4/10/2035 2:07', 'Apples', '152'],
#  ['4/10/2035 18:10', 'Bananas', '23'],
#  ['4/10/2035 2:40', 'Strawberries', '98']]

# %%
example_data[0][0]
# Out:
# '4/5/2035 13:34'

# %%
example_data[0][2]
# Out:
# '73'

# %%
example_data[6][1]
# Out:
# 'Strawberries'

# %%
example_data[4][2]
# Out:
# '152'

# %%
import csv

# %%
example_file = open('example3.csv')

# %%
example_reader = csv.reader(example_file)

# %%
for row in example_reader:
    print('Row #' + str(example_reader.line_num) + ' ' + str(row))
# Out:
# Row #1 ['4/5/2035 13:34', 'Apples', '73']
# Row #2 ['4/5/2035 3:41', 'Cherries', '85']
# Row #3 ['4/6/2035 12:46', 'Pears', '14']
# Row #4 ['4/8/2035 8:59', 'Oranges', '52']
# Row #5 ['4/10/2035 2:07', 'Apples', '152']
# Row #6 ['4/10/2035 18:10', 'Bananas', '23']
# Row #7 ['4/10/2035 2:40', 'Strawberries', '98']

# %%
import csv

# %%
output_file = open('output.csv', 'w', newline='')

# %%
output_writer = csv.writer(output_file)

# %%
output_writer.writerow(['spam', 'eggs', 'ham', 'bacon'])
# Out:
# 21

# %%
output_writer.writerow(["Hello, World!", "eggs", "ham", "bacon"])
# Out:
# 32

# %%
output_writer.writerow([1,2,3.141596,4])
# Out:
# 16

# %%
output_file.close()

# %%
import csv

# %%
output_file = open('ouput.tsv', 'w', newline='')

# %%
output_writer = csv.writer(output_file, delimiter='\t', lineterminator='\n\n')

# %%
output_writer.writerow(['spam', 'bacon', 'ham', 'eggs'])
# Out:
# 21

# %%
output_writer.writerow(["Hello, World!", "bacon", "ham", "eggs"])
# Out:
# 30

# %%
output_writer.writerow([1,2,3.141596,4])
# Out:
# 16

# %%
output_file.close()

# %%
import csv

# %%
example_file = open('exampleWithHeader3.csv')

# %%
example_dict_reader = csv.DictReader(example_file)

# %%
example_dict_data = list(example_dict_reader)

# %%
example_dict_data
# Out:
# [{'Timestamp': '4/5/2025 13:34', 'Fruit': 'Apples', 'Quantity': '73'},
#  {'Timestamp': '4/5/2025 3:41', 'Fruit': 'Cherries', 'Quantity': '85'},
#  {'Timestamp': '4/6/2025 12:46', 'Fruit': 'Pears', 'Quantity': '14'},
#  {'Timestamp': '4/8/2025 8:59', 'Fruit': 'Oranges', 'Quantity': '52'},
#  {'Timestamp': '4/10/2025 2:07', 'Fruit': 'Apples', 'Quantity': '152'},
#  {'Timestamp': '4/10/2025 18:10', 'Fruit': 'Bananas', 'Quantity': '23'},
#  {'Timestamp': '4/10/2025 2:40', 'Fruit': 'Strawberries', 'Quantity': '98'}]

# %%
example_file = open('exampleWithHeader3.csv')

# %%
example_dict_reader = csv.DictReader(example_file)

# %%
for row in example_dict_reader:
    print(row['Timestamp'], row['Fruit'], row['Quantity'])
# Out:
# 4/5/2025 13:34 Apples 73
# 4/5/2025 3:41 Cherries 85
# 4/6/2025 12:46 Pears 14
# 4/8/2025 8:59 Oranges 52
# 4/10/2025 2:07 Apples 152
# 4/10/2025 18:10 Bananas 23
# 4/10/2025 2:40 Strawberries 98

# %%
import csv

# %%
example_file = open('exampleWithHeader3.csv')

# %%
example_dict_reader = csv.DictReader(example_file, ['time', 'name', 'amount'])

# %%
for row in example_dict_reader:
    print(row['time'], row['name'], row['amount'])
# Out:
# Timestamp Fruit Quantity
# 4/5/2025 13:34 Apples 73
# 4/5/2025 3:41 Cherries 85
# 4/6/2025 12:46 Pears 14
# 4/8/2025 8:59 Oranges 52
# 4/10/2025 2:07 Apples 152
# 4/10/2025 18:10 Bananas 23
# 4/10/2025 2:40 Strawberries 98

# %%
import csv

# %%
output_file = open('output.csv', 'w', newline='')

# %%
output_dict_writer = csv.DictWriter(output_file, ['Name', 'Pet', 'Phone'])

# %%
output_dict_writer.writeheader()
# Out:
# 16

# %%
output_dict_writer.writerow({'Name': 'Alice', 'Pet': 'cat', 'Phone': '555-1234'})
# Out:
# 20

# %%
output_dict_writer.writerow({'Name': 'Bob', 'Phone': '555-9999'})
# Out:
# 15

# %%
output_dict_writer.writerow({'Phone': '555-5555', 'Name': 'Carol', 'Pet': 'dog'})
# Out:
# 20

# %%
output_file.close()

# %%
import json

# %%
json_string = '{"name": "Alice Doe", "age": 30, "car": null, "programmer": true, "address": {"street": "100 Larkin St.", "city": "San Francisco", "zip": "94102"}, "phone": [{"type": "mobile", "number": "415-555-7890"}, {"type":  "work", "number": "415-555-1234"}]}'

# %%
python_data = json.loads(json_string)

# %%
python_data
# Out:
# {'name': 'Alice Doe',
#  'age': 30,
#  'car': None,
#  'programmer': True,
#  'address': {'street': '100 Larkin St.',
#   'city': 'San Francisco',
#   'zip': '94102'},
#  'phone': [{'type': 'mobile', 'number': '415-555-7890'},
#   {'type': 'work', 'number': '415-555-1234'}]}

# %%
import json

# %%
python_data = {
    "name": "Alice Doe",
    "age": 30,
    "car": None,
    "programmer": True,
    "address": {"street": "100 Larkin St.", "city": "San Francisco", "zip": "94102"},
    "phone": [
        {"type": "mobile", "number": "415-555-7890"},
        {"type": "work", "number": "415-555-1234"},
    ],
}

# %%
json_string = json.dumps(python_data)

# %%
print(json_string)
# Out:
# {"name": "Alice Doe", "age": 30, "car": null, "programmer": true, "address": {"street": "100 Larkin St.", "city": "San Francisco", "zip": "94102"}, "phone": [{"type": "mobile", "number": "415-555-7890"}, {"type": "work", "number": "415-555-1234"}]}

# %%
json_string = json.dumps(python_data, indent=2)

# %%
print(json_string)
# Out:
# {
#   "name": "Alice Doe",
#   "age": 30,
#   "car": null,
#   "programmer": true,
#   "address": {
#     "street": "100 Larkin St.",
#     "city": "San Francisco",
#     "zip": "94102"
#   },
#   "phone": [
#     {
#       "type": "mobile",
#       "number": "415-555-7890"
#     },
#     {
#       "type": "work",
#       "number": "415-555-1234"
#     }
#   ]
# }
