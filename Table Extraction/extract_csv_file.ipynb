# %%
import pandas as pd

# %%
# reading 1 csv file from the url or website
ef_premier25 = pd.read_csv("https://football-data.co.uk/mmz4281/2526/E0.csv")

# %%
# showing dataframe
ef_premier25
# Out:
#     Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...          ...          ...   ...   ...  ..   ...
# 205  E0  07/01/2026  19:30       Fulham      Chelsea     2     1   H     0
# 206  E0  07/01/2026  19:30     Man City     Brighton     1     1   D     1
# 207  E0  07/01/2026  20:15      Burnley   Man United     2     2   D     1
# 208  E0  07/01/2026  20:15    Newcastle        Leeds     4     3   H     1
# 209  E0  08/01/2026  20:00      Arsenal    Liverpool     0     0   D     0
#
# ...

# %%
# renaming columns
ef_premier25.rename(
    columns={"FTHG": "home_goals",
    "FTAG": "away_goals"}, inplace=True)

# %%
# renamed dataframes
ef_premier25
# Out:
#     Div        Date   Time     HomeTeam     AwayTeam  home_goals  away_goals  \
# 0    E0  15/08/2025  20:00    Liverpool  Bournemouth           4           2
# 1    E0  16/08/2025  12:30  Aston Villa    Newcastle           0           0
# 2    E0  16/08/2025  15:00     Brighton       Fulham           1           1
# 3    E0  16/08/2025  15:00   Sunderland     West Ham           3           0
# 4    E0  16/08/2025  15:00    Tottenham      Burnley           3           0
# ..   ..         ...    ...          ...          ...         ...         ...
# 205  E0  07/01/2026  19:30       Fulham      Chelsea           2           1
# 206  E0  07/01/2026  19:30     Man City     Brighton           1           1
# 207  E0  07/01/2026  20:15      Burnley   Man United           2           2
# 208  E0  07/01/2026  20:15    Newcastle        Leeds           4           3
# 209  E0  08/01/2026  20:00      Arsenal    Liverpool           0           0
#
# ...

# %%
ef_championship = pd.read_csv("https://football-data.co.uk/mmz4281/2526/E1.csv")

# %%
ef_championship
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E1  08/08/2025  20:00     Birmingham      Ipswich     1     1   D     0
# 1    E1  09/08/2025  12:30       Charlton      Watford     1     0   H     0
# 2    E1  09/08/2025  12:30       Coventry         Hull     0     0   D     0
# 3    E1  09/08/2025  12:30    Southampton      Wrexham     2     1   H     0
# 4    E1  09/08/2025  15:00  Middlesbrough      Swansea     1     0   H     0
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 302  E1  04/01/2026  15:00          Derby      Wrexham     1     2   A     1
# 303  E1  04/01/2026  15:00  Middlesbrough  Southampton     4     0   H     0
# 304  E1  04/01/2026  15:00       Millwall      Swansea     2     1   H     1
# 305  E1  04/01/2026  15:00        Norwich        Stoke     0     2   A     0
# 306  E1  05/01/2026  20:00      Leicester    West Brom     2     1   H     1
#
# ...

# %%
ef_championship.rename(columns={"FTHG": "HomeGoals",
                                "FTAG": "AwayGoals"},inplace=True)

# %%
ef_championship
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  HomeGoals  AwayGoals  \
# 0    E1  08/08/2025  20:00     Birmingham      Ipswich          1          1
# 1    E1  09/08/2025  12:30       Charlton      Watford          1          0
# 2    E1  09/08/2025  12:30       Coventry         Hull          0          0
# 3    E1  09/08/2025  12:30    Southampton      Wrexham          2          1
# 4    E1  09/08/2025  15:00  Middlesbrough      Swansea          1          0
# ..   ..         ...    ...            ...          ...        ...        ...
# 302  E1  04/01/2026  15:00          Derby      Wrexham          1          2
# 303  E1  04/01/2026  15:00  Middlesbrough  Southampton          4          0
# 304  E1  04/01/2026  15:00       Millwall      Swansea          2          1
# 305  E1  04/01/2026  15:00        Norwich        Stoke          0          2
# 306  E1  05/01/2026  20:00      Leicester    West Brom          2          1
#
# ...
