# %%
import time

# %%
time.time()
# Out:
# 1770875327.3338525

# %%
import time

# %%
time.ctime()
# Out:
# 'Thu Feb 12 11:22:28 2026'

# %%
this_moment = time.time()

# %%
time.ctime(this_moment)
# Out:
# 'Thu Feb 12 11:22:37 2026'

# %%
import time

# %%
for i in range(3):
    print('Tick')
    time.sleep(1)
    print('Tock')
    time.sleep(1)
# Out:
# Tick
# Tock
# Tick
# Tock
# Tick
# Tock
