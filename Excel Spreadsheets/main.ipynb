# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example3.xlsx')

# %%
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
wb.sheetnames
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
sheet = wb['Sheet3']

# %%
sheet
# Out:
# <Worksheet "Sheet3">

# %%
type(sheet)
# Out:
# openpyxl.worksheet.worksheet.Worksheet

# %%
sheet.title
# Out:
# 'Sheet3'

# %%
active_sheet = wb.active

# %%
active_sheet
# Out:
# <Worksheet "Sheet1">

# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('example3.xlsx')

# %%
sheet = wb['Sheet1']

# %%
sheet['A1']
# Out:
# <Cell 'Sheet1'.A1>

# %%
sheet['A1'].value
# Out:
# datetime.datetime(2035, 4, 5, 13, 34, 2)

# %%
b = sheet['B1']

# %%
b.value
# Out:
# 'Apples'

# %%
f'Row {b.row}, Column {b.column} is {b.value}'
# Out:
# 'Row 1, Column 2 is Apples'

# %%
f'Cell {b.coordinate} is {b.value}'
# Out:
# 'Cell B1 is Apples'

# %%
sheet['C1'].value
# Out:
# 73

# %%
sheet.cell(row=1, column=2)
# Out:
# <Cell 'Sheet1'.B1>

# %%
sheet.cell(row=1, column=2).value
# Out:
# 'Apples'

# %%
for i in range(1, 8, 2):
    print(i, sheet.cell(row=i, column=2).value)
# Out:
# 1 Apples
# 3 Pears
# 5 Apples
# 7 Strawberries

# %%
sheet.max_row
# Out:
# 7

# %%
sheet.max_column
# Out:
# 3

# %%
import openpyxl

# %%
from openpyxl.utils import get_column_letter, column_index_from_string

# %%
get_column_letter(5)
# Out:
# 'E'

# %%
get_column_letter(27)
# Out:
# 'AA'

# %%
get_column_letter(88)
# Out:
# 'CJ'

# %%
get_column_letter(998)
# Out:
# 'ALJ'

# %%
get_column_letter(17576)
# Out:
# 'YYZ'

# %%
wb = openpyxl.load_workbook('example3.xlsx')

# %%
sheet = wb['Sheet1']

# %%
get_column_letter(sheet.max_column)
# Out:
# 'C'

# %%
column_index_from_string('ZZZ')
# Out:
# 18278

# %%
column_index_from_string('A')
# Out:
# 1

# %%
sheet['A1':'C3']
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),
#  (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>),
#  (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>, <Cell 'Sheet1'.C3>))

# %%
for row_of_column_obj in sheet['A1':'C3']:
    for cell_obj in row_of_column_obj:
        print(cell_obj.coordinate, cell_obj.value)
    print("--- End of row ---")
# Out:
# A1 2035-04-05 13:34:02
# B1 Apples
# C1 73
# --- End of row ---
# A2 2035-04-05 03:41:23
# B2 Cherries
# C2 85
# --- End of row ---
# A3 2035-04-06 12:46:51
# B3 Pears
# C3 14
# --- End of row ---

# %%
list(sheet.columns)[1]
# Out:
# (<Cell 'Sheet1'.B1>,
#  <Cell 'Sheet1'.B2>,
#  <Cell 'Sheet1'.B3>,
#  <Cell 'Sheet1'.B4>,
#  <Cell 'Sheet1'.B5>,
#  <Cell 'Sheet1'.B6>,
#  <Cell 'Sheet1'.B7>)

# %%
for cell_obj in list(sheet.columns)[1]:
    print(cell_obj.value)
# Out:
# Apples
# Cherries
# Pears
# Oranges
# Apples
# Bananas
# Strawberries

# %%
import census2010

# %%
census2010.allData["AK"]["Fairbanks North Star"]
# Out:
# {'pop': 97581, 'tracts': 19}

# %%
fairbanks_north_star_pop = census2010.allData['AK']['Fairbanks North Star']['pop']

# %%
print(f'The 2010 population of Fairbancks North Star is {fairbanks_north_star_pop}')
# Out:
# The 2010 population of Fairbancks North Star is 97581
