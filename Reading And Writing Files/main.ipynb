# %%
from pathlib import Path

# %%
Path('spam','bacon','eggs')
# Out:
# WindowsPath('spam/bacon/eggs')

# %%
Path('spam') / 'bacon' / 'eggs'
# Out:
# WindowsPath('spam/bacon/eggs')

# %%
import os

# %%
Path.cwd()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files')

# %%
os.chdir("d:/PROGRAMMES/Code Arena/Automation/")

# %%
Path.cwd()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation')

# %%
Path.home()
# Out:
# WindowsPath('C:/Users/Raj Tiwari')

# %%
os.chdir("d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files")

# %%
Path.cwd()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files')

# %%
os.makedirs("d://PROGRAMMES/Code Arena/Automation/Reading And Writing Files/delicious/walnuts/waffles")

# %%
Path(r'd://PROGRAMMES/Code Arena/Automation/Reading And Writing Files/spam').mkdir()

# %%
Path("my/relative/path")
# Out:
# WindowsPath('my/relative/path')

# %%
Path.cwd() / Path("my/relative/path")
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/my/relative/path')

# %%
Path("my/relative/path").absolute()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/my/relative/path')

# %%
Path.home() / Path("my/relative/path")
# Out:
# WindowsPath('C:/Users/Raj Tiwari/my/relative/path')

# %%
# Getting the parts of a filepath

# %%
p = Path('C://User/Al/spam.txt')

# %%
p.anchor
# Out:
# 'C:\\'

# %%
p.drive
# Out:
# 'C:'

# %%
p.name
# Out:
# 'spam.txt'

# %%
p.parent
# Out:
# WindowsPath('C:/User/Al')

# %%
p.stem
# Out:
# 'spam'

# %%
p.suffix
# Out:
# '.txt'

# %%
p.parts
# Out:
# ('C:\\', 'User', 'Al', 'spam.txt')

# %%
p.parts[0]
# Out:
# 'C:\\'

# %%
p.parts[0:2]
# Out:
# ('C:\\', 'User')

# %%
Path.cwd()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files')

# %%
Path.cwd().parents[0]
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation')

# %%
Path.cwd().parents[1]
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena')

# %%
Path.cwd().parents[2]
# Out:
# WindowsPath('d:/PROGRAMMES')

# %%
Path.cwd().parents[3]
# Out:
# WindowsPath('d:/')

# %%
Path.cwd()
# Out:
# WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files')

# %%
# Finding files sizes and timestamps

# %%
calc_file = Path("d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/spam/calc.exe")

# %%
calc_file.stat()
# Out:
# os.stat_result(st_mode=16895, st_ino=1970324837044036, st_dev=6104093251677478068, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1768795046, st_mtime=1768794847, st_ctime=1768794847)

# %%
calc_file.stat().st_size
# Out:
# 0

# %%
calc_file.stat().st_mtime
# Out:
# 1768794847.509422

# %%
import time

# %%
time.asctime(time.localtime(calc_file.stat().st_mtime))
# Out:
# 'Mon Jan 19 09:24:07 2026'

# %%
p = Path("d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files")

# %%
p.glob('*')

# %%
list(p.glob('*'))
# Out:
# [WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/delicious'),
#  WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/main.ipynb'),
#  WindowsPath('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/spam')]

# %%
for name in Path('d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files').glob('*'):
    print(name)
# Out:
# d:\PROGRAMMES\Code Arena\Automation\Reading And Writing Files\delicious
# d:\PROGRAMMES\Code Arena\Automation\Reading And Writing Files\main.ipynb
# d:\PROGRAMMES\Code Arena\Automation\Reading And Writing Files\spam

# %%
# Checking path validity

# %%
win_dir = Path("d://PROGRAMMES")

# %%
not_exists_dir = Path("d://PROGRAMMES/Code Arena/Automation/does/not/exit")

# %%
calc_file_path = Path(
    "d:/PROGRAMMES/Code Arena/Automation/Reading And Writing Files/spam/calc.docx"
)

# %%
calc_file_path.is_file()
# Out:
# True

# %%
calc_file_path.is_dir()
# Out:
# False

# %%
not_exists_dir.exists()
# Out:
# False

# %%
win_dir.exists()
# Out:
# True

# %%
# checking drive

# %%
d_drive = Path("d:/")

# %%
d_drive.exists()
# Out:
# True

# %%
# Reading and writing the file

# %%
p = Path('spam.txt')

# %%
p.write_text("Hello, World!")
# Out:
# 13

# %%
p.read_text()
# Out:
# 'Hello, World!'

# %%
p.write_text("Hello, World! Again!")
# Out:
# 20
