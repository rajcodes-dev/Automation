# %%
import pypdf

# %%
reader = pypdf.PdfReader('Recursion_Chapter1.pdf')

# %%
len(reader.pages)
# Out:
# 18

# %%
# Making a first 5 pages of the pdf

# %%
import pypdf

# %%
writer = pypdf.PdfWriter()

# %%
writer.append("Recursion_Chapter1.pdf", (0, 5))

# %%
with open("first_five_pages.pdf", "wb") as file:
    writer.write(file)

# %%
# we can also use list in case of tuple

# %%
# writer.append('Recursion_Chapter1.pdf', [0,1,2,3,4])

# %%
writer.merge(3, 'Recursion_Chapter1.pdf', (0, 5))

# %%
with open("first_five_pages.pdf", "wb") as file:
    writer.write(file)

# %%
# rotating a pdf

# %%
import pypdf

# %%
writer = pypdf.PdfWriter()

# %%
writer.append('Recursion_Chapter1.pdf')

# %%
for i in range(len(writer.pages)):
    writer.pages[i].rotate(90)

# %%
with open('rotated.pdf', 'wb') as file:
    writer.write(file)

# %%
# added blank pages

# %%
import pypdf

# %%
writer = pypdf.PdfWriter()

# %%
writer.append('Recursion_Chapter1.pdf')

# %%
writer.add_blank_page()
# Out:
# {'/Type': '/Page',
#  '/Resources': {},
#  '/MediaBox': [0.0, 0.0, 546, 708],
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 19,
#   '/Kids': [IndirectObject(4, 0, 1234186513424),
#    IndirectObject(63, 0, 1234186513424),
#    IndirectObject(94, 0, 1234186513424),
#    IndirectObject(109, 0, 1234186513424),
#    IndirectObject(119, 0, 1234186513424),
#    IndirectObject(125, 0, 1234186513424),
#    IndirectObject(132, 0, 1234186513424),
#    IndirectObject(140, 0, 1234186513424),
#    IndirectObject(147, 0, 1234186513424),
#    IndirectObject(156, 0, 1234186513424),
#    IndirectObject(162, 0, 1234186513424),
#    IndirectObject(174, 0, 1234186513424),
#    IndirectObject(176, 0, 1234186513424),
#    IndirectObject(190, 0, 1234186513424),
#    IndirectObject(192, 0, 1234186513424),
#    IndirectObject(198, 0, 1234186513424),
#    IndirectObject(200, 0, 1234186513424),
#    IndirectObject(202, 0, 1234186513424),
#    IndirectObject(227, 0, 1234186513424)]}}

# %%
writer.insert_blank_page(index=3)
# Out:
# {'/Type': '/Page',
#  '/Parent': NullObject,
#  '/Resources': {},
#  '/MediaBox': RectangleObject([0.0, 0.0, 546, 708])}

# %%
with open('with_blank.pdf', 'wb') as file:
    writer.write(file)

# %%
import pypdf

# %%
writer = pypdf.PdfWriter()

# %%
writer.append('Recursion_Chapter1.pdf')

# %%
watermark_page = pypdf.PdfReader('watermark.pdf').pages[0]

# %%
for page in writer.pages:
    page.merge_page(watermark_page, over=False)

# %%
with open('with_watermark.pdf', 'wb') as file:
    writer.write(file)
