# %%
import ezsheets

# %%
ss = ezsheets.Spreadsheet()

# %%
ss.tittle = "My New Spreedsheet"

# %%
ss.url
# Out:
# 'https://docs.google.com/spreadsheets/d/1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8/'

# %%
ss.id
# Out:
# '1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8'

# %%
ss1 = ezsheets.Spreadsheet("https://autbor.com/examplegs")

# %%
ss2 = ezsheets.Spreadsheet('https://docs.google.com/spreadsheets/d/1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI/')

# %%
ss3 = ezsheets.Spreadsheet('1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI')

# %%
ss1 == ss2 == ss3
# Out:
# True

# %%
ss = ezsheets.upload('produceSales3.xlsx')

# %%
ss.title
# Out:
# 'produceSales3'

# %%
ezsheets.listSpreadsheets()
# Out:
# {'1Vi3Cgg5WcbNAuvoHh0pkfc5NfifKTb2gTKOgNQMdDEU': 'produceSales3',
#  '1eFCF2P0rT_vKAKKEi3BseSyirPysyt-MMY2b4Ktco-w': 'produceSales3',
#  '1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8': 'Untitled spreadsheet',
#  '1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI': 'Sweigart Books (DO NOT DELETE)'}

# %%
import ezsheets

# %%
example_ss = ezsheets.Spreadsheet('https://autbor.com/examplegs')

# %%
ss = ezsheets.Spreadsheet()

# %%
example_ss.sheets[0].copyTo(ss)

# %%
ss.sheets[0].delete()

# %%
ss.url
# Out:
# 'https://docs.google.com/spreadsheets/d/102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI/'

# %%
ss.title
# Out:
# 'Untitled spreadsheet'

# %%
ss.title = 'Sweigart Books'

# %%
ss.id
# Out:
# '102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI'

# %%
ss.url
# Out:
# 'https://docs.google.com/spreadsheets/d/102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI/'

# %%
ss.sheetTitles
# Out:
# ('Copy of Books',)

# %%
ss.sheets
# Out:
# (<Sheet sheetId=2139369720, title='Copy of Books', rowCount=1000, columnCount=26>,)

# %%
ss['Copy of Books']
# Out:
# <Sheet sheetId=2139369720, title='Copy of Books', rowCount=1000, columnCount=26>

# %%
ss.sheets[0]
# Out:
# <Sheet sheetId=2139369720, title='Copy of Books', rowCount=1000, columnCount=26>

# %%
ss.Sheet('New blank sheet')

# %%
ss.sheets[1].delete()

# %%
ss.refresh()

# %%
# Downloading and uploading spreadsheets

# %%
import ezsheets

# %%
ss = ezsheets.Spreadsheet("https://autbor.com/examplegs")

# %%
ss.title
# Out:
# 'Sweigart Books (DO NOT DELETE)'

# %%
ss.downloadAsExcel()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).xlsx'

# %%
ss.downloadAsODS()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).ods'

# %%
ss.downloadAsCSV()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).csv'

# %%
ss.downloadAsHTML()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).zip'

# %%
ss.downloadAsTSV()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).tsv'

# %%
ss.downloadAsPDF()
# Out:
# 'Sweigart_Books_(DO_NOT_DELETE).pdf'

# %%
ss.downloadAsExcel('my_excel.xlsx')
# Out:
# 'my_excel.xlsx'

# %%
ss = ezsheets.Spreadsheet()

# %%
ezsheets.listSpreadsheets()
# Out:
# {'1hSUh5-yk247ibERh2nNDtHJ2c55cygEPrjjE2hrny9E': 'Untitled spreadsheet',
#  '1eFCF2P0rT_vKAKKEi3BseSyirPysyt-MMY2b4Ktco-w': 'produceSales',
#  '102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI': 'Sweigart Books',
#  '1Vi3Cgg5WcbNAuvoHh0pkfc5NfifKTb2gTKOgNQMdDEU': 'produceSales3',
#  '1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8': 'Untitled spreadsheet',
#  '1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI': 'Sweigart Books (DO NOT DELETE)'}

# %%
ss.delete()

# %%
ezsheets.listSpreadsheets()
# Out:
# {'1hSUh5-yk247ibERh2nNDtHJ2c55cygEPrjjE2hrny9E': 'Untitled spreadsheet',
#  '1eFCF2P0rT_vKAKKEi3BseSyirPysyt-MMY2b4Ktco-w': 'produceSales',
#  '102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI': 'Sweigart Books',
#  '1Vi3Cgg5WcbNAuvoHh0pkfc5NfifKTb2gTKOgNQMdDEU': 'produceSales3',
#  '1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8': 'Untitled spreadsheet',
#  '1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI': 'Sweigart Books (DO NOT DELETE)'}

# %%
ss.delete(permanent=True)

# %%
ezsheets.listSpreadsheets()
# Out:
# {'1eFCF2P0rT_vKAKKEi3BseSyirPysyt-MMY2b4Ktco-w': 'produceSales',
#  '102yXQ-vn34q3MAEmPB94w5z9Diy9s3Y8l5LC3U7cnaI': 'Sweigart Books',
#  '1Vi3Cgg5WcbNAuvoHh0pkfc5NfifKTb2gTKOgNQMdDEU': 'produceSales3',
#  '1v4jpquK6R7lk8goO8Dwh_Bgst_8NamGdmGrsMA5b3k8': 'Untitled spreadsheet',
#  '1TzOJxhNKr15tzdZxTqtQ3EmDP6em_elnbtmZIcyu8vI': 'Sweigart Books (DO NOT DELETE)'}

# %%
import ezsheets

# %%
ss = ezsheets.Spreadsheet()

# %%
sheet2 = ss.Sheet('spam')

# %%
sheet3 = ss.Sheet('egg')

# %%
ss.sheets
# Out:
# (<Sheet sheetId=0, title='Sheet1', rowCount=1000, columnCount=26>,
#  <Sheet sheetId=1138773086, title='egg', rowCount=1000, columnCount=26>,
#  <Sheet sheetId=1883448151, title='spam', rowCount=1000, columnCount=26>)

# %%
ss.sheets[0]
# Out:
# <Sheet sheetId=0, title='Sheet1', rowCount=1000, columnCount=26>

# %%
ss.sheetTitles
# Out:
# ('Sheet1', 'egg', 'spam')

# %%
# reading and writing data

# %%
import ezsheets

# %%
ss = ezsheets.Spreadsheet()

# %%
ss.title = 'My Spreadsheet'

# %%
sheet = ss.sheets[0]

# %%
sheet.title
# Out:
# 'Sheet1'

# %%
sheet['A1'] = 'Name'

# %%
sheet['B1'] = 'Age'

# %%
sheet['C1'] = 'Favorite Movie'

# %%
sheet['A1']
# Out:
# 'Name'

# %%
sheet['A2']
# Out:
# ''

# %%
sheet[3,1]
# Out:
# 'Favorite Movie'

# %%
sheet['A2'] = 'Rohan'

# %%
sheet['B2'] = 19

# %%
sheet['C2'] = 'KGF'

# %%
sheet['B2']
# Out:
# 19

# %%
ss.url
# Out:
# 'https://docs.google.com/spreadsheets/d/1WyWH9-Gu4COLyqKoXmP1wDYryJJrpjnnuvw8iZTY6Wg/'

# %%
# Addressing Columns and Rows

# %%
ezsheets.convertAddress('A3')
# Out:
# (1, 3)

# %%
ezsheets.convertAddress(1,3)
# Out:
# 'A3'

# %%
ezsheets.getColumnLetterOf(999)
# Out:
# 'ALK'

# %%
ezsheets.getColumnNumberOf('ZZZ')
# Out:
# 18278

# %%
ezsheets.getColumnLetterOf(888)
# Out:
# 'AHD'

# %%
ss = ezsheets.Spreadsheet('produceSales3')

# %%
sheet = ss.sheets[0]

# %%
sheet.getColumn(1)
# Out:
# ['PRODUCE',
#  'Potatoes',
#  'Okra',
#  'Fava beans',
#  'Watermelon',
#  'Garlic',
#  'Parsnips',
#  'Asparagus',
#  'Avocados',
#  'Celery',
#  'Okra',
#  'Spinach',
#  'Cucumber',
#  'Apricots',
#  'Okra',
#  'Fava beans',
#  'Watermelon',
#  'Ginger',
#  'Corn',
#  'Grapefruit',
#  'Ginger',
#  'Eggplant',
#  'Cucumber',
#  'Green cabbage',
#  'Eggplant',
#  'Yellow peppers',
#  'Garlic',
#  'Grapes',
#  'Watermelon',
#  'Cherries',
#  'Apples',
#  'Grapefruit',
#  'Grapes',
#  'Green beans',
#  'Tomatoes',
#  'Apricots',
#  'Red onion',
#  'Strawberries',
#  'Grapes',
#  'Ginger',
#  'Strawberries',
#  'Fava beans',
#  'Yellow peppers',
#  'Papaya',
#  'Butternut squash',
#  'Apricots',
#  'Avocados',
#  'Butternut squash',
#  'Celery',
#  'Bananas',
#  'Lettuce',
#  'Carrots',
#  'Asparagus',
#  'Ginger',
#  'Daikon',
#  'Lime',
#  'Watermelon',
#  'Apricots',
#  'Green beans',
#  'Strawberries',
#  'Watermelon',
#  'Green peppers',
#  'Bananas',
#  'Apples',
#  'Spinach',
#  'Avocados',
#  'Okra',
#  'Papaya',
#  'Beets',
#  'Green beans',
#  'Grapefruit',
#  'Butternut squash',
#  'Parsnips',
#  'Cherries',
#  'Papaya',
#  'Bananas',
#  'Eggplant',
#  'Apricots',
#  'Eggplant',
#  'Coconuts',
#  'Grapefruit',
#  'Grapes',
#  'Avocados',
#  'Avocados',
#  'Apples',
#  'Daikon',
#  'Lime',
#  'Lime',
#  'Daikon',
#  'Garlic',
#  'Apples',
#  'Orange',
#  'Spinach',
#  'Okra',
#  'Celery',
#  'Lemon',
#  'Garlic',
#  'Spinach',
#  'Watermelon',
#  'Coconuts',
#  'Apricots',
#  'Lettuce',
#  'Tomatoes',
#  'Strawberries',
#  'Coconuts',
#  'Parsnips',
#  'Brussels sprouts',
#  'Celery',
#  'Grapes',
#  'Coconuts',
#  'Coconuts',
#  'Grapes',
#  'Ginger',
#  'Grapefruit',
#  'Daikon',
#  'Corn',
#  'Daikon',
#  'Orange',
#  'Eggplant',
#  'Brussels sprouts',
#  'Ginger',
#  'Coconuts',
#  'Lettuce',
#  'Carrots',
#  'Orange',
#  'Parsnips',
#  'Yellow peppers',
#  'Avocados',
#  'Coconuts',
#  'Beets',
#  'Celery',
#  'Green beans',
#  'Butternut squash',
#  'Asparagus',
#  'Fava beans',
#  'Green cabbage',
#  'Apples',
#  'Lettuce',
#  'Bananas',
#  'Red onion',
#  'Parsnips',
#  'Carrots',
#  'Lemon',
#  'Parsnips',
#  'Ginger',
#  'Daikon',
#  'Butternut squash',
#  'Strawberries',
#  'Asparagus',
#  'Celery',
#  'Spinach',
#  'Green beans',
#  'Yellow peppers',
#  'Lettuce',
#  'Green beans',
#  'Asparagus',
#  'Apples',
#  'Eggplant',
#  'Potatoes',
#  'Fava beans',
#  'Watermelon',
#  'Butternut squash',
#  'Spinach',
#  'Yellow peppers',
#  'Green beans',
#  'Cucumber',
#  'Grapefruit',
#  'Orange',
#  'Lettuce',
#  'Eggplant',
#  'Eggplant',
#  'Apples',
#  'Tomatoes',
#  'Yellow peppers',
#  'Fava beans',
#  'Cucumber',
#  'Brussels sprouts',
#  'Kale',
#  'Red onion',
#  'Carrots',
#  'Tomatoes',
#  'Green beans',
#  'Green cabbage',
#  'Fava beans',
#  'Green beans',
#  'Parsnips',
#  'Orange',
#  'Coconuts',
#  'Papaya',
#  'Lime',
#  'Potatoes',
#  'Grapefruit',
#  'Yellow peppers',
#  'Apples',
#  'Red onion',
#  'Beets',
#  'Grapes',
#  'Beets',
#  'Strawberries',
#  'Strawberries',
#  'Eggplant',
#  'Yellow peppers',
#  'Yellow peppers',
#  'Daikon',
#  'Cucumber',
#  'Bananas',
#  'Butternut squash',
#  'Tomatoes',
#  'Bok choy',
#  'Papaya',
#  'Beets',
#  'Garlic',
#  'Avocados',
#  'Corn',
#  'Lettuce',
#  'Apricots',
#  'Butternut squash',
#  'Green peppers',
#  'Grapes',
#  'Bok choy',
#  'Orange',
#  'Papaya',
#  'Okra',
#  'Yellow peppers',
#  'Daikon',
#  'Papaya',
#  'Daikon',
#  'Brussels sprouts',
#  'Butternut squash',
#  'Watermelon',
#  'Carrots',
#  'Bananas',
#  'Yellow peppers',
#  'Orange',
#  'Celery',
#  'Apples',
#  'Potatoes',
#  'Garlic',
#  'Celery',
#  'Lime',
#  'Watermelon',
#  'Lemon',
#  'Ginger',
#  'Orange',
#  'Grapes',
#  'Daikon',
#  'Potatoes',
#  'Green cabbage',
#  'Carrots',
#  'Yellow peppers',
#  'Papaya',
#  'Yellow peppers',
#  'Fava beans',
#  'Kale',
#  'Fava beans',
#  'Tomatoes',
#  'Lemon',
#  'Fava beans',
#  'Corn',
#  'Ginger',
#  'Carrots',
#  'Beets',
#  'Carrots',
#  'Apples',
#  'Cherries',
#  'Lettuce',
#  'Eggplant',
#  'Lime',
#  'Strawberries',
#  'Daikon',
#  'Cherries',
#  'Ginger',
#  'Papaya',
#  'Corn',
#  'Carrots',
#  'Apricots',
#  'Yellow peppers',
#  'Orange',
#  'Daikon',
#  'Apricots',
#  'Potatoes',
#  'Spinach',
#  'Spinach',
#  'Eggplant',
#  'Avocados',
#  'Asparagus',
#  'Corn',
#  'Lime',
#  'Watermelon',
#  'Apples',
#  'Kale',
#  'Lemon',
#  'Celery',
#  'Cucumber',
#  'Fava beans',
#  'Spinach',
#  'Grapes',
#  'Yellow peppers',
#  'Strawberries',
#  'Cherries',
#  'Apples',
#  'Bok choy',
#  'Strawberries',
#  'Lime',
#  'Lettuce',
#  'Grapes',
#  'Butternut squash',
#  'Okra',
#  'Green peppers',
#  'Corn',
#  'Okra',
#  'Apricots',
#  'Parsnips',
#  'Daikon',
#  'Papaya',
#  'Okra',
#  'Lettuce',
#  'Yellow peppers',
#  'Green beans',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Apples',
#  'Okra',
#  'Asparagus',
#  'Beets',
#  'Garlic',
#  'Cucumber',
#  'Green cabbage',
#  'Apricots',
#  'Daikon',
#  'Daikon',
#  'Bananas',
#  'Apricots',
#  'Strawberries',
#  'Spinach',
#  'Carrots',
#  'Lemon',
#  'Green peppers',
#  'Eggplant',
#  'Avocados',
#  'Bananas',
#  'Avocados',
#  'Lime',
#  'Celery',
#  'Strawberries',
#  'Bok choy',
#  'Celery',
#  'Apples',
#  'Bok choy',
#  'Bananas',
#  'Lemon',
#  'Asparagus',
#  'Brussels sprouts',
#  'Bananas',
#  'Green cabbage',
#  'Green peppers',
#  'Butternut squash',
#  'Potatoes',
#  'Strawberries',
#  'Lemon',
#  'Celery',
#  'Spinach',
#  'Parsnips',
#  'Avocados',
#  'Brussels sprouts',
#  'Lime',
#  'Papaya',
#  'Coconuts',
#  'Spinach',
#  'Orange',
#  'Carrots',
#  'Lemon',
#  'Lime',
#  'Kale',
#  'Beets',
#  'Asparagus',
#  'Corn',
#  'Parsnips',
#  'Ginger',
#  'Corn',
#  'Apricots',
#  'Lettuce',
#  'Potatoes',
#  'Garlic',
#  'Eggplant',
#  'Coconuts',
#  'Asparagus',
#  'Tomatoes',
#  'Papaya',
#  'Celery',
#  'Orange',
#  'Ginger',
#  'Potatoes',
#  'Parsnips',
#  'Yellow peppers',
#  'Grapefruit',
#  'Green peppers',
#  'Corn',
#  'Carrots',
#  'Eggplant',
#  'Coconuts',
#  'Green cabbage',
#  'Apples',
#  'Cherries',
#  'Brussels sprouts',
#  'Strawberries',
#  'Bok choy',
#  'Yellow peppers',
#  'Okra',
#  'Orange',
#  'Avocados',
#  'Spinach',
#  'Apricots',
#  'Coconuts',
#  'Grapes',
#  'Okra',
#  'Eggplant',
#  'Bok choy',
#  'Eggplant',
#  'Beets',
#  'Garlic',
#  'Kale',
#  'Lime',
#  'Avocados',
#  'Lime',
#  'Papaya',
#  'Lettuce',
#  'Red onion',
#  'Fava beans',
#  'Okra',
#  'Beets',
#  'Coconuts',
#  'Grapes',
#  'Ginger',
#  'Asparagus',
#  'Apples',
#  'Garlic',
#  'Corn',
#  'Potatoes',
#  'Apricots',
#  'Spinach',
#  'Grapefruit',
#  'Cucumber',
#  'Kale',
#  'Lemon',
#  'Green beans',
#  'Celery',
#  'Potatoes',
#  'Asparagus',
#  'Eggplant',
#  'Cucumber',
#  'Garlic',
#  'Carrots',
#  'Red onion',
#  'Lettuce',
#  'Apples',
#  'Yellow peppers',
#  'Bok choy',
#  'Apples',
#  'Orange',
#  'Bok choy',
#  'Lime',
#  'Celery',
#  'Brussels sprouts',
#  'Celery',
#  'Beets',
#  'Avocados',
#  'Yellow peppers',
#  'Cherries',
#  'Carrots',
#  'Daikon',
#  'Parsnips',
#  'Cherries',
#  'Celery',
#  'Kale',
#  'Okra',
#  'Lettuce',
#  'Carrots',
#  'Fava beans',
#  'Daikon',
#  'Fava beans',
#  'Yellow peppers',
#  'Carrots',
#  'Corn',
#  'Yellow peppers',
#  'Kale',
#  'Grapefruit',
#  'Apricots',
#  'Fava beans',
#  'Green peppers',
#  'Cherries',
#  'Orange',
#  'Spinach',
#  'Lime',
#  'Bok choy',
#  'Carrots',
#  'Red onion',
#  'Bananas',
#  'Beets',
#  'Grapes',
#  'Garlic',
#  'Lime',
#  'Spinach',
#  'Fava beans',
#  'Grapes',
#  'Beets',
#  'Cherries',
#  'Coconuts',
#  'Eggplant',
#  'Spinach',
#  'Grapes',
#  'Ginger',
#  'Apples',
#  'Tomatoes',
#  'Watermelon',
#  'Okra',
#  'Ginger',
#  'Papaya',
#  'Orange',
#  'Fava beans',
#  'Lime',
#  'Okra',
#  'Garlic',
#  'Brussels sprouts',
#  'Ginger',
#  'Avocados',
#  'Green beans',
#  'Strawberries',
#  'Yellow peppers',
#  'Grapes',
#  'Eggplant',
#  'Green beans',
#  'Grapefruit',
#  'Cherries',
#  'Beets',
#  'Beets',
#  'Butternut squash',
#  'Ginger',
#  'Carrots',
#  'Grapes',
#  'Carrots',
#  'Fava beans',
#  'Yellow peppers',
#  'Potatoes',
#  'Yellow peppers',
#  'Apricots',
#  'Cherries',
#  'Asparagus',
#  'Tomatoes',
#  'Fava beans',
#  'Coconuts',
#  'Yellow peppers',
#  'Grapes',
#  'Green peppers',
#  'Bananas',
#  'Bok choy',
#  'Green beans',
#  'Strawberries',
#  'Avocados',
#  'Eggplant',
#  'Daikon',
#  'Apples',
#  'Papaya',
#  'Cucumber',
#  'Butternut squash',
#  'Daikon',
#  'Papaya',
#  'Yellow peppers',
#  'Carrots',
#  'Parsnips',
#  'Yellow peppers',
#  'Garlic',
#  'Daikon',
#  'Cherries',
#  'Butternut squash',
#  'Green beans',
#  'Carrots',
#  'Papaya',
#  'Lettuce',
#  'Asparagus',
#  'Green peppers',
#  'Brussels sprouts',
#  'Green peppers',
#  'Okra',
#  'Green cabbage',
#  'Ginger',
#  'Cherries',
#  'Potatoes',
#  'Lemon',
#  'Orange',
#  'Butternut squash',
#  'Cucumber',
#  'Spinach',
#  'Lettuce',
#  'Orange',
#  'Daikon',
#  'Potatoes',
#  'Garlic',
#  'Garlic',
#  'Grapefruit',
#  'Lettuce',
#  'Potatoes',
#  'Lettuce',
#  'Asparagus',
#  'Avocados',
#  'Green beans',
#  'Butternut squash',
#  'Green beans',
#  'Cherries',
#  'Fava beans',
#  'Corn',
#  'Spinach',
#  'Daikon',
#  'Okra',
#  'Green cabbage',
#  'Fava beans',
#  'Watermelon',
#  'Cucumber',
#  'Red onion',
#  'Watermelon',
#  'Potatoes',
#  'Spinach',
#  'Daikon',
#  'Cherries',
#  'Red onion',
#  'Red onion',
#  'Carrots',
#  'Bananas',
#  'Orange',
#  'Daikon',
#  'Green cabbage',
#  'Eggplant',
#  'Fava beans',
#  'Lemon',
#  'Corn',
#  'Brussels sprouts',
#  'Grapes',
#  'Lemon',
#  'Yellow peppers',
#  'Orange',
#  'Coconuts',
#  'Orange',
#  'Bok choy',
#  'Green beans',
#  'Okra',
#  'Avocados',
#  'Lettuce',
#  'Ginger',
#  'Potatoes',
#  'Okra',
#  'Daikon',
#  'Apricots',
#  'Okra',
#  'Potatoes',
#  'Lemon',
#  'Apricots',
#  'Lemon',
#  'Cherries',
#  'Bananas',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Coconuts',
#  'Asparagus',
#  'Asparagus',
#  'Potatoes',
#  'Eggplant',
#  'Red onion',
#  'Bok choy',
#  'Yellow peppers',
#  'Grapefruit',
#  'Watermelon',
#  'Eggplant',
#  'Apricots',
#  'Asparagus',
#  'Carrots',
#  'Bananas',
#  'Yellow peppers',
#  'Asparagus',
#  'Garlic',
#  'Papaya',
#  'Cherries',
#  'Orange',
#  'Watermelon',
#  'Tomatoes',
#  'Watermelon',
#  'Grapefruit',
#  'Asparagus',
#  'Avocados',
#  'Okra',
#  'Spinach',
#  'Fava beans',
#  'Butternut squash',
#  'Kale',
#  'Papaya',
#  'Avocados',
#  'Garlic',
#  'Lettuce',
#  'Yellow peppers',
#  'Orange',
#  'Coconuts',
#  'Celery',
#  'Grapefruit',
#  'Asparagus',
#  'Grapefruit',
#  'Kale',
#  'Orange',
#  'Okra',
#  'Strawberries',
#  'Cucumber',
#  'Lime',
#  'Corn',
#  'Lime',
#  'Beets',
#  'Celery',
#  'Bok choy',
#  'Grapefruit',
#  'Bananas',
#  'Eggplant',
#  'Avocados',
#  'Brussels sprouts',
#  'Daikon',
#  'Tomatoes',
#  'Papaya',
#  'Lime',
#  'Bananas',
#  'Coconuts',
#  'Potatoes',
#  'Spinach',
#  'Kale',
#  'Celery',
#  'Corn',
#  'Fava beans',
#  'Beets',
#  'Yellow peppers',
#  'Butternut squash',
#  'Apples',
#  'Lemon',
#  'Apples',
#  'Garlic',
#  'Garlic',
#  'Fava beans',
#  'Kale',
#  'Garlic',
#  'Grapes',
#  'Strawberries',
#  'Corn',
#  'Bananas',
#  'Bananas',
#  'Lime',
#  'Avocados',
#  'Lettuce',
#  'Apples',
#  'Avocados',
#  'Avocados',
#  'Grapes',
#  'Coconuts',
#  'Green beans',
#  'Papaya',
#  'Apricots',
#  'Fava beans',
#  'Parsnips',
#  'Coconuts',
#  'Watermelon',
#  'Asparagus',
#  'Tomatoes',
#  'Avocados',
#  'Tomatoes',
#  'Brussels sprouts',
#  'Bok choy',
#  'Tomatoes',
#  'Strawberries',
#  'Garlic',
#  'Butternut squash',
#  'Avocados',
#  'Apples',
#  'Garlic',
#  'Butternut squash',
#  'Orange',
#  'Spinach',
#  'Okra',
#  'Cherries',
#  'Papaya',
#  'Lemon',
#  'Lettuce',
#  'Red onion',
#  'Parsnips',
#  'Kale',
#  'Papaya',
#  'Ginger',
#  'Ginger',
#  'Green peppers',
#  'Red onion',
#  'Parsnips',
#  'Lettuce',
#  'Celery',
#  'Apricots',
#  'Potatoes',
#  'Green beans',
#  'Carrots',
#  'Grapes',
#  'Brussels sprouts',
#  'Strawberries',
#  'Ginger',
#  'Papaya',
#  'Apricots',
#  'Brussels sprouts',
#  'Lettuce',
#  'Green cabbage',
#  'Potatoes',
#  'Green cabbage',
#  'Apricots',
#  'Red onion',
#  'Lime',
#  'Parsnips',
#  'Papaya',
#  'Lettuce',
#  'Lemon',
#  'Coconuts',
#  'Asparagus',
#  'Asparagus',
#  'Watermelon',
#  'Fava beans',
#  'Strawberries',
#  'Celery',
#  'Apricots',
#  'Cucumber',
#  'Green peppers',
#  'Corn',
#  'Papaya',
#  'Green cabbage',
#  'Kale',
#  'Potatoes',
#  'Beets',
#  'Parsnips',
#  'Green peppers',
#  'Orange',
#  'Watermelon',
#  'Asparagus',
#  'Corn',
#  'Green peppers',
#  'Celery',
#  'Coconuts',
#  'Grapes',
#  'Daikon',
#  'Carrots',
#  'Watermelon',
#  'Yellow peppers',
#  'Apricots',
#  'Lime',
#  'Ginger',
#  'Lemon',
#  'Red onion',
#  'Grapefruit',
#  'Lemon',
#  'Strawberries',
#  'Watermelon',
#  'Cucumber',
#  'Bok choy',
#  'Lemon',
#  'Brussels sprouts',
#  'Avocados',
#  'Kale',
#  'Kale',
#  'Papaya',
#  'Kale',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Celery',
#  'Okra',
#  'Fava beans',
#  'Grapes',
#  'Lemon',
#  'Yellow peppers',
#  'Kale',
#  'Red onion',
#  'Papaya',
#  'Grapes',
#  'Apples',
#  'Avocados',
#  'Bananas',
#  'Tomatoes',
#  'Carrots',
#  'Corn',
#  'Carrots',
#  'Butternut squash',
#  'Green peppers',
#  'Strawberries',
#  'Orange',
#  'Daikon',
#  'Red onion',
#  'Grapes',
#  'Corn',
#  'Lettuce',
#  'Kale',
#  'Green cabbage',
#  'Grapefruit',
#  'Cucumber',
#  'Yellow peppers',
#  'Watermelon',
#  'Beets',
#  'Avocados',
#  'Eggplant',
#  'Apricots',
#  'Fava beans',
#  'Grapes',
#  'Tomatoes',
#  'Avocados',
#  'Beets',
#  'Orange',
#  'Green beans',
#  'Grapes',
#  'Strawberries',
#  'Grapes',
#  'Lettuce',
#  'Tomatoes',
#  'Beets',
#  'Celery',
#  'Grapes',
#  'Grapefruit',
#  'Bok choy',
#  'Beets',
#  'Lemon',
#  'Cucumber',
#  'Grapefruit',
#  'Fava beans',
#  'Eggplant',
#  'Carrots',
#  'Cherries',
#  'Tomatoes',
#  'Tomatoes',
#  'Grapefruit',
#  'Lime',
#  'Coconuts',
#  'Cherries',
#  'Coconuts',
#  'Asparagus',
#  'Lemon',
#  'Apples',
#  'Corn',
#  'Tomatoes',
#  'Orange',
#  'Orange',
#  'Green peppers',
#  'Apricots',
#  'Yellow peppers',
#  'Avocados',
#  'Carrots',
#  'Bananas',
#  'Cherries',
#  'Tomatoes',
#  'Papaya',
#  'Garlic',
#  'Potatoes',
#  'Bok choy',
#  'Asparagus',
#  'Kale',
#  'Corn',
#  'Grapefruit',
#  'Beets',
#  'Watermelon',
#  'Green peppers',
#  'Potatoes',
#  'Okra',
#  'Carrots',
#  'Daikon',
#  'Lime',
#  'Cucumber',
#  'Butternut squash',
#  'Kale',
#  'Apples',
#  'Asparagus',
#  'Brussels sprouts',
#  'Eggplant',
#  'Celery',
#  'Strawberries',
#  'Green beans',
#  'Cucumber',
#  'Green beans',
#  'Green beans',
#  'Lettuce',
#  'Grapefruit',
#  'Watermelon',
#  'Carrots',
#  'Fava beans',
#  'Fava beans',
#  'Brussels sprouts',
#  'Green cabbage',
#  'Corn',
#  'Apricots',
#  'Butternut squash',
#  'Potatoes',
#  'Grapes',
#  'Grapefruit',
#  'Beets',
#  'Green peppers',
#  'Corn',
#  'Orange',
#  ...]

# %%
sheet.getRow
# Out:
# <bound method Sheet.getRow of <Sheet sheetId=127084939, title='Sheet', rowCount=23758, columnCount=6>>

# %%
sheet.getRow(1)
# Out:
# ['PRODUCE', 'COST PER POUND', 'POUNDS SOLD', 'TOTAL', '', '']

# %%
sheet.getRow(2)
# Out:
# ['Potatoes', '0.86', '21.6', '18.58', '', '']

# %%
sheet.getColumn('A')
# Out:
# ['PRODUCE',
#  'Potatoes',
#  'Okra',
#  'Fava beans',
#  'Watermelon',
#  'Garlic',
#  'Parsnips',
#  'Asparagus',
#  'Avocados',
#  'Celery',
#  'Okra',
#  'Spinach',
#  'Cucumber',
#  'Apricots',
#  'Okra',
#  'Fava beans',
#  'Watermelon',
#  'Ginger',
#  'Corn',
#  'Grapefruit',
#  'Ginger',
#  'Eggplant',
#  'Cucumber',
#  'Green cabbage',
#  'Eggplant',
#  'Yellow peppers',
#  'Garlic',
#  'Grapes',
#  'Watermelon',
#  'Cherries',
#  'Apples',
#  'Grapefruit',
#  'Grapes',
#  'Green beans',
#  'Tomatoes',
#  'Apricots',
#  'Red onion',
#  'Strawberries',
#  'Grapes',
#  'Ginger',
#  'Strawberries',
#  'Fava beans',
#  'Yellow peppers',
#  'Papaya',
#  'Butternut squash',
#  'Apricots',
#  'Avocados',
#  'Butternut squash',
#  'Celery',
#  'Bananas',
#  'Lettuce',
#  'Carrots',
#  'Asparagus',
#  'Ginger',
#  'Daikon',
#  'Lime',
#  'Watermelon',
#  'Apricots',
#  'Green beans',
#  'Strawberries',
#  'Watermelon',
#  'Green peppers',
#  'Bananas',
#  'Apples',
#  'Spinach',
#  'Avocados',
#  'Okra',
#  'Papaya',
#  'Beets',
#  'Green beans',
#  'Grapefruit',
#  'Butternut squash',
#  'Parsnips',
#  'Cherries',
#  'Papaya',
#  'Bananas',
#  'Eggplant',
#  'Apricots',
#  'Eggplant',
#  'Coconuts',
#  'Grapefruit',
#  'Grapes',
#  'Avocados',
#  'Avocados',
#  'Apples',
#  'Daikon',
#  'Lime',
#  'Lime',
#  'Daikon',
#  'Garlic',
#  'Apples',
#  'Orange',
#  'Spinach',
#  'Okra',
#  'Celery',
#  'Lemon',
#  'Garlic',
#  'Spinach',
#  'Watermelon',
#  'Coconuts',
#  'Apricots',
#  'Lettuce',
#  'Tomatoes',
#  'Strawberries',
#  'Coconuts',
#  'Parsnips',
#  'Brussels sprouts',
#  'Celery',
#  'Grapes',
#  'Coconuts',
#  'Coconuts',
#  'Grapes',
#  'Ginger',
#  'Grapefruit',
#  'Daikon',
#  'Corn',
#  'Daikon',
#  'Orange',
#  'Eggplant',
#  'Brussels sprouts',
#  'Ginger',
#  'Coconuts',
#  'Lettuce',
#  'Carrots',
#  'Orange',
#  'Parsnips',
#  'Yellow peppers',
#  'Avocados',
#  'Coconuts',
#  'Beets',
#  'Celery',
#  'Green beans',
#  'Butternut squash',
#  'Asparagus',
#  'Fava beans',
#  'Green cabbage',
#  'Apples',
#  'Lettuce',
#  'Bananas',
#  'Red onion',
#  'Parsnips',
#  'Carrots',
#  'Lemon',
#  'Parsnips',
#  'Ginger',
#  'Daikon',
#  'Butternut squash',
#  'Strawberries',
#  'Asparagus',
#  'Celery',
#  'Spinach',
#  'Green beans',
#  'Yellow peppers',
#  'Lettuce',
#  'Green beans',
#  'Asparagus',
#  'Apples',
#  'Eggplant',
#  'Potatoes',
#  'Fava beans',
#  'Watermelon',
#  'Butternut squash',
#  'Spinach',
#  'Yellow peppers',
#  'Green beans',
#  'Cucumber',
#  'Grapefruit',
#  'Orange',
#  'Lettuce',
#  'Eggplant',
#  'Eggplant',
#  'Apples',
#  'Tomatoes',
#  'Yellow peppers',
#  'Fava beans',
#  'Cucumber',
#  'Brussels sprouts',
#  'Kale',
#  'Red onion',
#  'Carrots',
#  'Tomatoes',
#  'Green beans',
#  'Green cabbage',
#  'Fava beans',
#  'Green beans',
#  'Parsnips',
#  'Orange',
#  'Coconuts',
#  'Papaya',
#  'Lime',
#  'Potatoes',
#  'Grapefruit',
#  'Yellow peppers',
#  'Apples',
#  'Red onion',
#  'Beets',
#  'Grapes',
#  'Beets',
#  'Strawberries',
#  'Strawberries',
#  'Eggplant',
#  'Yellow peppers',
#  'Yellow peppers',
#  'Daikon',
#  'Cucumber',
#  'Bananas',
#  'Butternut squash',
#  'Tomatoes',
#  'Bok choy',
#  'Papaya',
#  'Beets',
#  'Garlic',
#  'Avocados',
#  'Corn',
#  'Lettuce',
#  'Apricots',
#  'Butternut squash',
#  'Green peppers',
#  'Grapes',
#  'Bok choy',
#  'Orange',
#  'Papaya',
#  'Okra',
#  'Yellow peppers',
#  'Daikon',
#  'Papaya',
#  'Daikon',
#  'Brussels sprouts',
#  'Butternut squash',
#  'Watermelon',
#  'Carrots',
#  'Bananas',
#  'Yellow peppers',
#  'Orange',
#  'Celery',
#  'Apples',
#  'Potatoes',
#  'Garlic',
#  'Celery',
#  'Lime',
#  'Watermelon',
#  'Lemon',
#  'Ginger',
#  'Orange',
#  'Grapes',
#  'Daikon',
#  'Potatoes',
#  'Green cabbage',
#  'Carrots',
#  'Yellow peppers',
#  'Papaya',
#  'Yellow peppers',
#  'Fava beans',
#  'Kale',
#  'Fava beans',
#  'Tomatoes',
#  'Lemon',
#  'Fava beans',
#  'Corn',
#  'Ginger',
#  'Carrots',
#  'Beets',
#  'Carrots',
#  'Apples',
#  'Cherries',
#  'Lettuce',
#  'Eggplant',
#  'Lime',
#  'Strawberries',
#  'Daikon',
#  'Cherries',
#  'Ginger',
#  'Papaya',
#  'Corn',
#  'Carrots',
#  'Apricots',
#  'Yellow peppers',
#  'Orange',
#  'Daikon',
#  'Apricots',
#  'Potatoes',
#  'Spinach',
#  'Spinach',
#  'Eggplant',
#  'Avocados',
#  'Asparagus',
#  'Corn',
#  'Lime',
#  'Watermelon',
#  'Apples',
#  'Kale',
#  'Lemon',
#  'Celery',
#  'Cucumber',
#  'Fava beans',
#  'Spinach',
#  'Grapes',
#  'Yellow peppers',
#  'Strawberries',
#  'Cherries',
#  'Apples',
#  'Bok choy',
#  'Strawberries',
#  'Lime',
#  'Lettuce',
#  'Grapes',
#  'Butternut squash',
#  'Okra',
#  'Green peppers',
#  'Corn',
#  'Okra',
#  'Apricots',
#  'Parsnips',
#  'Daikon',
#  'Papaya',
#  'Okra',
#  'Lettuce',
#  'Yellow peppers',
#  'Green beans',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Apples',
#  'Okra',
#  'Asparagus',
#  'Beets',
#  'Garlic',
#  'Cucumber',
#  'Green cabbage',
#  'Apricots',
#  'Daikon',
#  'Daikon',
#  'Bananas',
#  'Apricots',
#  'Strawberries',
#  'Spinach',
#  'Carrots',
#  'Lemon',
#  'Green peppers',
#  'Eggplant',
#  'Avocados',
#  'Bananas',
#  'Avocados',
#  'Lime',
#  'Celery',
#  'Strawberries',
#  'Bok choy',
#  'Celery',
#  'Apples',
#  'Bok choy',
#  'Bananas',
#  'Lemon',
#  'Asparagus',
#  'Brussels sprouts',
#  'Bananas',
#  'Green cabbage',
#  'Green peppers',
#  'Butternut squash',
#  'Potatoes',
#  'Strawberries',
#  'Lemon',
#  'Celery',
#  'Spinach',
#  'Parsnips',
#  'Avocados',
#  'Brussels sprouts',
#  'Lime',
#  'Papaya',
#  'Coconuts',
#  'Spinach',
#  'Orange',
#  'Carrots',
#  'Lemon',
#  'Lime',
#  'Kale',
#  'Beets',
#  'Asparagus',
#  'Corn',
#  'Parsnips',
#  'Ginger',
#  'Corn',
#  'Apricots',
#  'Lettuce',
#  'Potatoes',
#  'Garlic',
#  'Eggplant',
#  'Coconuts',
#  'Asparagus',
#  'Tomatoes',
#  'Papaya',
#  'Celery',
#  'Orange',
#  'Ginger',
#  'Potatoes',
#  'Parsnips',
#  'Yellow peppers',
#  'Grapefruit',
#  'Green peppers',
#  'Corn',
#  'Carrots',
#  'Eggplant',
#  'Coconuts',
#  'Green cabbage',
#  'Apples',
#  'Cherries',
#  'Brussels sprouts',
#  'Strawberries',
#  'Bok choy',
#  'Yellow peppers',
#  'Okra',
#  'Orange',
#  'Avocados',
#  'Spinach',
#  'Apricots',
#  'Coconuts',
#  'Grapes',
#  'Okra',
#  'Eggplant',
#  'Bok choy',
#  'Eggplant',
#  'Beets',
#  'Garlic',
#  'Kale',
#  'Lime',
#  'Avocados',
#  'Lime',
#  'Papaya',
#  'Lettuce',
#  'Red onion',
#  'Fava beans',
#  'Okra',
#  'Beets',
#  'Coconuts',
#  'Grapes',
#  'Ginger',
#  'Asparagus',
#  'Apples',
#  'Garlic',
#  'Corn',
#  'Potatoes',
#  'Apricots',
#  'Spinach',
#  'Grapefruit',
#  'Cucumber',
#  'Kale',
#  'Lemon',
#  'Green beans',
#  'Celery',
#  'Potatoes',
#  'Asparagus',
#  'Eggplant',
#  'Cucumber',
#  'Garlic',
#  'Carrots',
#  'Red onion',
#  'Lettuce',
#  'Apples',
#  'Yellow peppers',
#  'Bok choy',
#  'Apples',
#  'Orange',
#  'Bok choy',
#  'Lime',
#  'Celery',
#  'Brussels sprouts',
#  'Celery',
#  'Beets',
#  'Avocados',
#  'Yellow peppers',
#  'Cherries',
#  'Carrots',
#  'Daikon',
#  'Parsnips',
#  'Cherries',
#  'Celery',
#  'Kale',
#  'Okra',
#  'Lettuce',
#  'Carrots',
#  'Fava beans',
#  'Daikon',
#  'Fava beans',
#  'Yellow peppers',
#  'Carrots',
#  'Corn',
#  'Yellow peppers',
#  'Kale',
#  'Grapefruit',
#  'Apricots',
#  'Fava beans',
#  'Green peppers',
#  'Cherries',
#  'Orange',
#  'Spinach',
#  'Lime',
#  'Bok choy',
#  'Carrots',
#  'Red onion',
#  'Bananas',
#  'Beets',
#  'Grapes',
#  'Garlic',
#  'Lime',
#  'Spinach',
#  'Fava beans',
#  'Grapes',
#  'Beets',
#  'Cherries',
#  'Coconuts',
#  'Eggplant',
#  'Spinach',
#  'Grapes',
#  'Ginger',
#  'Apples',
#  'Tomatoes',
#  'Watermelon',
#  'Okra',
#  'Ginger',
#  'Papaya',
#  'Orange',
#  'Fava beans',
#  'Lime',
#  'Okra',
#  'Garlic',
#  'Brussels sprouts',
#  'Ginger',
#  'Avocados',
#  'Green beans',
#  'Strawberries',
#  'Yellow peppers',
#  'Grapes',
#  'Eggplant',
#  'Green beans',
#  'Grapefruit',
#  'Cherries',
#  'Beets',
#  'Beets',
#  'Butternut squash',
#  'Ginger',
#  'Carrots',
#  'Grapes',
#  'Carrots',
#  'Fava beans',
#  'Yellow peppers',
#  'Potatoes',
#  'Yellow peppers',
#  'Apricots',
#  'Cherries',
#  'Asparagus',
#  'Tomatoes',
#  'Fava beans',
#  'Coconuts',
#  'Yellow peppers',
#  'Grapes',
#  'Green peppers',
#  'Bananas',
#  'Bok choy',
#  'Green beans',
#  'Strawberries',
#  'Avocados',
#  'Eggplant',
#  'Daikon',
#  'Apples',
#  'Papaya',
#  'Cucumber',
#  'Butternut squash',
#  'Daikon',
#  'Papaya',
#  'Yellow peppers',
#  'Carrots',
#  'Parsnips',
#  'Yellow peppers',
#  'Garlic',
#  'Daikon',
#  'Cherries',
#  'Butternut squash',
#  'Green beans',
#  'Carrots',
#  'Papaya',
#  'Lettuce',
#  'Asparagus',
#  'Green peppers',
#  'Brussels sprouts',
#  'Green peppers',
#  'Okra',
#  'Green cabbage',
#  'Ginger',
#  'Cherries',
#  'Potatoes',
#  'Lemon',
#  'Orange',
#  'Butternut squash',
#  'Cucumber',
#  'Spinach',
#  'Lettuce',
#  'Orange',
#  'Daikon',
#  'Potatoes',
#  'Garlic',
#  'Garlic',
#  'Grapefruit',
#  'Lettuce',
#  'Potatoes',
#  'Lettuce',
#  'Asparagus',
#  'Avocados',
#  'Green beans',
#  'Butternut squash',
#  'Green beans',
#  'Cherries',
#  'Fava beans',
#  'Corn',
#  'Spinach',
#  'Daikon',
#  'Okra',
#  'Green cabbage',
#  'Fava beans',
#  'Watermelon',
#  'Cucumber',
#  'Red onion',
#  'Watermelon',
#  'Potatoes',
#  'Spinach',
#  'Daikon',
#  'Cherries',
#  'Red onion',
#  'Red onion',
#  'Carrots',
#  'Bananas',
#  'Orange',
#  'Daikon',
#  'Green cabbage',
#  'Eggplant',
#  'Fava beans',
#  'Lemon',
#  'Corn',
#  'Brussels sprouts',
#  'Grapes',
#  'Lemon',
#  'Yellow peppers',
#  'Orange',
#  'Coconuts',
#  'Orange',
#  'Bok choy',
#  'Green beans',
#  'Okra',
#  'Avocados',
#  'Lettuce',
#  'Ginger',
#  'Potatoes',
#  'Okra',
#  'Daikon',
#  'Apricots',
#  'Okra',
#  'Potatoes',
#  'Lemon',
#  'Apricots',
#  'Lemon',
#  'Cherries',
#  'Bananas',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Coconuts',
#  'Asparagus',
#  'Asparagus',
#  'Potatoes',
#  'Eggplant',
#  'Red onion',
#  'Bok choy',
#  'Yellow peppers',
#  'Grapefruit',
#  'Watermelon',
#  'Eggplant',
#  'Apricots',
#  'Asparagus',
#  'Carrots',
#  'Bananas',
#  'Yellow peppers',
#  'Asparagus',
#  'Garlic',
#  'Papaya',
#  'Cherries',
#  'Orange',
#  'Watermelon',
#  'Tomatoes',
#  'Watermelon',
#  'Grapefruit',
#  'Asparagus',
#  'Avocados',
#  'Okra',
#  'Spinach',
#  'Fava beans',
#  'Butternut squash',
#  'Kale',
#  'Papaya',
#  'Avocados',
#  'Garlic',
#  'Lettuce',
#  'Yellow peppers',
#  'Orange',
#  'Coconuts',
#  'Celery',
#  'Grapefruit',
#  'Asparagus',
#  'Grapefruit',
#  'Kale',
#  'Orange',
#  'Okra',
#  'Strawberries',
#  'Cucumber',
#  'Lime',
#  'Corn',
#  'Lime',
#  'Beets',
#  'Celery',
#  'Bok choy',
#  'Grapefruit',
#  'Bananas',
#  'Eggplant',
#  'Avocados',
#  'Brussels sprouts',
#  'Daikon',
#  'Tomatoes',
#  'Papaya',
#  'Lime',
#  'Bananas',
#  'Coconuts',
#  'Potatoes',
#  'Spinach',
#  'Kale',
#  'Celery',
#  'Corn',
#  'Fava beans',
#  'Beets',
#  'Yellow peppers',
#  'Butternut squash',
#  'Apples',
#  'Lemon',
#  'Apples',
#  'Garlic',
#  'Garlic',
#  'Fava beans',
#  'Kale',
#  'Garlic',
#  'Grapes',
#  'Strawberries',
#  'Corn',
#  'Bananas',
#  'Bananas',
#  'Lime',
#  'Avocados',
#  'Lettuce',
#  'Apples',
#  'Avocados',
#  'Avocados',
#  'Grapes',
#  'Coconuts',
#  'Green beans',
#  'Papaya',
#  'Apricots',
#  'Fava beans',
#  'Parsnips',
#  'Coconuts',
#  'Watermelon',
#  'Asparagus',
#  'Tomatoes',
#  'Avocados',
#  'Tomatoes',
#  'Brussels sprouts',
#  'Bok choy',
#  'Tomatoes',
#  'Strawberries',
#  'Garlic',
#  'Butternut squash',
#  'Avocados',
#  'Apples',
#  'Garlic',
#  'Butternut squash',
#  'Orange',
#  'Spinach',
#  'Okra',
#  'Cherries',
#  'Papaya',
#  'Lemon',
#  'Lettuce',
#  'Red onion',
#  'Parsnips',
#  'Kale',
#  'Papaya',
#  'Ginger',
#  'Ginger',
#  'Green peppers',
#  'Red onion',
#  'Parsnips',
#  'Lettuce',
#  'Celery',
#  'Apricots',
#  'Potatoes',
#  'Green beans',
#  'Carrots',
#  'Grapes',
#  'Brussels sprouts',
#  'Strawberries',
#  'Ginger',
#  'Papaya',
#  'Apricots',
#  'Brussels sprouts',
#  'Lettuce',
#  'Green cabbage',
#  'Potatoes',
#  'Green cabbage',
#  'Apricots',
#  'Red onion',
#  'Lime',
#  'Parsnips',
#  'Papaya',
#  'Lettuce',
#  'Lemon',
#  'Coconuts',
#  'Asparagus',
#  'Asparagus',
#  'Watermelon',
#  'Fava beans',
#  'Strawberries',
#  'Celery',
#  'Apricots',
#  'Cucumber',
#  'Green peppers',
#  'Corn',
#  'Papaya',
#  'Green cabbage',
#  'Kale',
#  'Potatoes',
#  'Beets',
#  'Parsnips',
#  'Green peppers',
#  'Orange',
#  'Watermelon',
#  'Asparagus',
#  'Corn',
#  'Green peppers',
#  'Celery',
#  'Coconuts',
#  'Grapes',
#  'Daikon',
#  'Carrots',
#  'Watermelon',
#  'Yellow peppers',
#  'Apricots',
#  'Lime',
#  'Ginger',
#  'Lemon',
#  'Red onion',
#  'Grapefruit',
#  'Lemon',
#  'Strawberries',
#  'Watermelon',
#  'Cucumber',
#  'Bok choy',
#  'Lemon',
#  'Brussels sprouts',
#  'Avocados',
#  'Kale',
#  'Kale',
#  'Papaya',
#  'Kale',
#  'Butternut squash',
#  'Cucumber',
#  'Lettuce',
#  'Celery',
#  'Okra',
#  'Fava beans',
#  'Grapes',
#  'Lemon',
#  'Yellow peppers',
#  'Kale',
#  'Red onion',
#  'Papaya',
#  'Grapes',
#  'Apples',
#  'Avocados',
#  'Bananas',
#  'Tomatoes',
#  'Carrots',
#  'Corn',
#  'Carrots',
#  'Butternut squash',
#  'Green peppers',
#  'Strawberries',
#  'Orange',
#  'Daikon',
#  'Red onion',
#  'Grapes',
#  'Corn',
#  'Lettuce',
#  'Kale',
#  'Green cabbage',
#  'Grapefruit',
#  'Cucumber',
#  'Yellow peppers',
#  'Watermelon',
#  'Beets',
#  'Avocados',
#  'Eggplant',
#  'Apricots',
#  'Fava beans',
#  'Grapes',
#  'Tomatoes',
#  'Avocados',
#  'Beets',
#  'Orange',
#  'Green beans',
#  'Grapes',
#  'Strawberries',
#  'Grapes',
#  'Lettuce',
#  'Tomatoes',
#  'Beets',
#  'Celery',
#  'Grapes',
#  'Grapefruit',
#  'Bok choy',
#  'Beets',
#  'Lemon',
#  'Cucumber',
#  'Grapefruit',
#  'Fava beans',
#  'Eggplant',
#  'Carrots',
#  'Cherries',
#  'Tomatoes',
#  'Tomatoes',
#  'Grapefruit',
#  'Lime',
#  'Coconuts',
#  'Cherries',
#  'Coconuts',
#  'Asparagus',
#  'Lemon',
#  'Apples',
#  'Corn',
#  'Tomatoes',
#  'Orange',
#  'Orange',
#  'Green peppers',
#  'Apricots',
#  'Yellow peppers',
#  'Avocados',
#  'Carrots',
#  'Bananas',
#  'Cherries',
#  'Tomatoes',
#  'Papaya',
#  'Garlic',
#  'Potatoes',
#  'Bok choy',
#  'Asparagus',
#  'Kale',
#  'Corn',
#  'Grapefruit',
#  'Beets',
#  'Watermelon',
#  'Green peppers',
#  'Potatoes',
#  'Okra',
#  'Carrots',
#  'Daikon',
#  'Lime',
#  'Cucumber',
#  'Butternut squash',
#  'Kale',
#  'Apples',
#  'Asparagus',
#  'Brussels sprouts',
#  'Eggplant',
#  'Celery',
#  'Strawberries',
#  'Green beans',
#  'Cucumber',
#  'Green beans',
#  'Green beans',
#  'Lettuce',
#  'Grapefruit',
#  'Watermelon',
#  'Carrots',
#  'Fava beans',
#  'Fava beans',
#  'Brussels sprouts',
#  'Green cabbage',
#  'Corn',
#  'Apricots',
#  'Butternut squash',
#  'Potatoes',
#  'Grapes',
#  'Grapefruit',
#  'Beets',
#  'Green peppers',
#  'Corn',
#  'Orange',
#  ...]

# %%
sheet.getRow(3)
# Out:
# ['Okra', '2.26', '38.6', '87.24', '', '']

# %%
sheet.updateRow(3, ['Pumpkin', '11.50', '20', '230'])

# %%
sheet.getRow(3)
# Out:
# ['Pumpkin', '11.50', '20', '230', '', '']

# %%
columnOne = sheet.getColumn(1)

# %%
for i, value in enumerate(columnOne):
    columnOne[i] = value.upper()

# %%
sheet.updateColumn(1, columnOne)

# %%
rows = sheet.getRows()

# %%
rows[0]
# Out:
# ['PRODUCE', 'COST PER POUND', 'POUNDS SOLD', 'TOTAL', '', '']

# %%
rows[1]
# Out:
# ['POTATOES', '0.86', '21.6', '18.58', '', '']

# %%
rows[1][0] = 'PUMPKIN'

# %%
rows[1]
# Out:
# ['PUMPKIN', '0.86', '21.6', '18.58', '', '']

# %%
rows[2]
# Out:
# ['PUMPKIN', '11.50', '20', '230', '', '']

# %%
rows[10]
# Out:
# ['OKRA', '2.26', '40', '90.4', '', '']

# %%
rows[10][2] = '400'

# %%
rows[10][3] = '904'

# %%
rows[10]
# Out:
# ['OKRA', '2.26', '400', '904', '', '']

# %%
sheet.updateRows(rows)
